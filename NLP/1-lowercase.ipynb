# %%
text = "THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG"

lowercase_text = text.lower()
print(lowercase_text)  # Output: the quick brown fox jumps over the lazy dog
# Out:
# the quick brown fox jumps over the lazy dog
